# %%
from sklearn import datasets
digits = datasets.load_digits()
n = digits.target.shape[0]
import numpy as np
import random
random.seed(123)
indices = np.array(list(set([random.randint(0, n) for i in range(100)])))
labels = digits.target[indices]
data = digits.data[indices]

# %%
data
# Out:
# array([[  0.,   0.,   7., ...,   9.,   0.,   0.],
#        [  0.,   0.,   1., ...,   3.,   0.,   0.],
#        [  0.,   2.,   9., ...,  11.,   0.,   0.],
#        ...,
#        [  0.,   0.,   4., ...,   0.,   0.,   0.],
#        [  0.,   0.,   3., ...,   9.,   0.,   0.],
#        [  0.,   0.,   0., ...,   6.,   0.,   0.]])

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn import manifold
mds = manifold.MDS(n_components=2, max_iter=3000, eps=1e-9, random_state=123,
                   dissimilarity="euclidean", n_jobs=1)
mds
# Out:
# MDS(dissimilarity='euclidean', eps=1e-09, max_iter=3000, metric=True,
#   n_components=2, n_init=4, n_jobs=1, random_state=123, verbose=0)

# %%
data_mds = mds.fit(data).embedding_
data_mds
# Out:
# array([[-19.51303971, -20.41823645],
#        [ -4.07593511,   9.35897683],
#        [-31.00523503,  -7.67846859],
#        [-35.75764508,  10.44774877],
#        [  5.59026225, -17.29521269],
#        [ 11.97655306,  12.22829745],
#        [ 15.25794671,  31.05617523],
#        [-25.79056895,  29.88613377],
#        [-10.04741421, -26.52225104],
#        [-35.66520853,   1.16539859],
#        [-39.47468187,  22.63228924],
#        [ -6.93509794,  39.78971228],
#        [-20.95223628, -27.68618938],
#        [-10.38757908,  25.18008394],
#        [-17.77529191,   1.31227389],
#        [ 29.99031246,  16.54974674],
#        [-22.53093288,  25.53871594],
#        [ 36.07828582,  -4.8243011 ],
#        [-18.80800715,  11.64556649],
#        [  7.60907703,  43.50117329],
#        [ 14.19626422, -28.97827972],
#        [-16.47691626, -31.64881718],
#        [-30.72245981, -20.29590957],
#        [-16.71741647,  27.39585998],
#        [-36.43541554, -11.61842247],
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
color = ["#%06x" % random.randint(0, 0xAAAAAA) for i in range(0, data.shape[0])]
#scatter plot
from pylab import rcParams #set figure size
rcParams['figure.figsize'] = 12,9
for x, y, c in zip(data_mds[:,0], data_mds[:,1], color):
    plt.scatter(x,y,color=c)
#labels
for label, x, y, c in zip(labels, data_mds[:,0],data_mds[:,1], color):
    plt.annotate(label, xy = (x, y), xytext = (-0, 0),
        textcoords = 'offset points', ha = 'right', va = 'bottom', color=c)
plt.show()

# %%
from sklearn.manifold import TSNE
TSNE_model = TSNE(n_components=2, random_state = 1, perplexity=12, method="exact", n_iter = 1000, learning_rate = 100)
data_TSNE = TSNE_model.fit(data).embedding_
data_TSNE
# Out:
# array([[ 10.63971872,   1.49341571],
#        [  3.51667266,  -4.75906586],
#        [ 12.87161571,  -0.2826602 ],
#        [ -2.55230732,  -3.5729329 ],
#        [  5.35711611,  15.74322759],
#        [  2.32650434,   5.20847165],
#        [ -2.3179861 , -11.93668461],
#        [ -8.63728942,   1.49054305],
#        [  5.30046092,   1.24997256],
#        [ -2.50280218,  -2.54823035],
#        [ -5.09419852,   4.09222285],
#        [ -2.60099284,  -5.03201159],
#        [  6.81109724,   1.74526179],
#        [ -8.30049749,   0.24135449],
#        [  3.86833975,  -1.94312284],
#        [ -9.73035841,  10.15610207],
#        [-12.75161953,  -0.99451145],
#        [-11.66278933, -13.44403277],
#        [ -1.57940874,  -1.19851209],
#        [ -6.71600089,  -6.65514333],
#        [  5.97031069,  12.1732983 ],
#        [  8.76933455,  -7.322248  ],
#        [  9.66031373,  -6.47943569],
#        [-10.72018547,  -1.0914852 ],
#        [ 13.75364699,  -1.52403677],
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
color = ["#%06x" % random.randint(0, 0xAAAAAA) for i in range(0, data.shape[0])]
#scatter plot
from pylab import rcParams #set figure size
rcParams['figure.figsize'] = 12,9
for x, y, c in zip(data_mds[:,0], data_mds[:,1], color):
    plt.scatter(x,y,color=c)
#labels
for label, x, y, c in zip(labels, data_mds[:,0],data_mds[:,1], color):
    plt.annotate(label, xy = (x, y), xytext = (-0, 0),
        textcoords = 'offset points', ha = 'right', va = 'bottom', color=c)
plt.show()

# %%
print('HMW3')
# Out:
# HMW3

# %%
from gensim.models import Word2Vec
from gensim.models.word2vec import LineSentence
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# train word2vec on your file
model0 = Word2Vec(LineSentence("/Users/40515/Desktop/enwik8"), size=50, window=8, min_count=5, workers=8)
#size is dimension
# Out:
# 2017-11-11 22:20:57,805 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2017-11-11 22:20:57,806 : INFO : collecting all words and their counts
# 2017-11-11 22:20:57,808 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-11-11 22:20:57,880 : INFO : PROGRESS: at sentence #10000, processed 131145 words, keeping 35864 word types
# 2017-11-11 22:20:57,955 : INFO : PROGRESS: at sentence #20000, processed 255992 words, keeping 63279 word types
# 2017-11-11 22:20:58,041 : INFO : PROGRESS: at sentence #30000, processed 413253 words, keeping 93158 word types
# 2017-11-11 22:20:58,125 : INFO : PROGRESS: at sentence #40000, processed 561673 words, keeping 119771 word types
# 2017-11-11 22:20:58,200 : INFO : PROGRESS: at sentence #50000, processed 691292 words, keeping 142452 word types
# 2017-11-11 22:20:58,278 : INFO : PROGRESS: at sentence #60000, processed 829170 words, keeping 164547 word types
# ...

# %%
from gensim.models.word2vec import Text8Corpus
data = Text8Corpus("/Users/40515/Desktop/enwik8")

# %%
model0

# %%
model0.most_similar('president')
# Out:
# [('President', 0.909220814704895),
#  ('minister', 0.9065984487533569),
#  ('president,', 0.8898121118545532),
#  ('Minister', 0.882117509841919),
#  ('cabinet', 0.8761940002441406),
#  ('candidate', 0.8752190470695496),
#  ('appointed', 0.8640222549438477),
#  ('Prime', 0.8595004081726074),
#  ('Governor', 0.8556042909622192),
#  ('President,', 0.8396975994110107)]

# %%
model0.most_similar('election')
# Out:
# [('elections,', 0.9015548229217529),
#  ('elections', 0.8909623622894287),
#  ('presidential', 0.8903005719184875),
#  ('election.', 0.884824812412262),
#  ('candidate', 0.8718427419662476),
#  ('party', 0.8705160021781921),
#  ('parliamentary', 0.8676315546035767),
#  ('election,', 0.8632755875587463),
#  ('parliament', 0.8620434999465942),
#  ('Senate', 0.849998950958252)]

# %%
model = Word2Vec(data, size=50, window=8, min_count=5, workers=8)
# Out:
# 2017-11-11 23:04:55,857 : WARNING : consider setting layer size to a multiple of 4 for greater performance
# 2017-11-11 23:04:55,860 : INFO : collecting all words and their counts
# 2017-11-11 23:04:55,863 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2017-11-11 23:05:01,533 : INFO : collected 1439384 word types from a corpus of 13303002 raw words and 1331 sentences
# 2017-11-11 23:05:01,534 : INFO : Loading a fresh vocabulary
# 2017-11-11 23:05:02,367 : INFO : min_count=5 retains 144146 unique words (10% of original 1439384, drops 1295238)
# 2017-11-11 23:05:02,368 : INFO : min_count=5 leaves 11616047 word corpus (87% of original 13303002, drops 1686955)
# 2017-11-11 23:05:02,760 : INFO : deleting the raw counts dictionary of 1439384 items
# 2017-11-11 23:05:02,805 : INFO : sample=0.001 downsamples 30 most-common words
# 2017-11-11 23:05:02,806 : INFO : downsampling leaves estimated 9254700 word corpus (79.7% of prior 11616047)
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
embedding = pd.read_csv("/Users/40515/Desktop/vectors.txt", sep=" ", header=None)
embedding = embedding[500:700] #take the words 300-500
names = embedding[0]
embedding = embedding.drop([0,51],1)
embedding[:4]
# Out:
#            1         2         3         4         5         6         7   \
# 500 -0.001606 -0.067836  0.229238  0.541479 -0.007498 -0.003841 -0.098353
# 501  0.705197  0.491692  0.472500 -0.554815 -0.055529  0.151175 -0.154701
# 502  0.017174  0.249119 -0.076060 -0.107295 -0.111648 -0.331655 -0.430153
# 503  0.657896 -0.248971 -0.018684 -0.939071 -0.072028  0.047444 -0.249120
#
#            8         9         10    ...           41        42        43  \
# 500  0.577135  0.032968 -0.394978    ...    -0.386026  0.619508  0.904121
# 501  0.002599  0.337987 -0.485766    ...     0.373028  0.188832  0.488650
# 502  0.234631  0.090145 -0.476770    ...     0.249506  0.010696  0.356206
# 503  0.372754 -0.086951 -0.575756    ...    -0.144854 -0.103164  0.382052
#
#            44        45        46        47        48        49        50
# 500 -0.470696  0.738204 -0.185316 -0.405761  0.340095 -0.106618 -0.109973
# 501 -0.328036  0.060625 -0.065709 -0.652115  0.100060 -0.852628 -0.379585
# ...

# %%
import random
pca = PCA(n_components=2)

embedding_normal = StandardScaler(with_std=False).fit_transform(embedding)
pca.fit(embedding_normal)
embedding_normal_pca = pca.fit_transform(embedding_normal)
from pylab import rcParams #set figure size
rcParams['figure.figsize'] = 15, 15
plt.scatter(embedding_normal_pca[:,0], embedding_normal_pca[:,1], s = 0)
for label, x, y in zip(names, embedding_normal_pca[:, 0], embedding_normal_pca[:, 1]):
    plt.annotate(label, xy = (x, y), xytext = (0,0),
        textcoords = 'offset points', ha = 'center', va = 'center', bbox = None,
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'), 
                 color = "#%06x" % random.randint(0, 0xAAAAAA))
